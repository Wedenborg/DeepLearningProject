# %%
# Imports:
import os
import numpy as np
import mne
import matplotlib.pyplot as plt
import scipy
from scipy import signal
import matplotlib
from scipy.linalg import svd
from sklearn.metrics import confusion_matrix

# %%
# Dataload from LoadData Iben

# Extra good good stuff to import 
import random

## IMPORTANT: Test.edf cannot be from 1Sept folder!!!!

## Path to the EEG files
#path = 'E:/DeepLearningEEG/dataEEG/Original participant EEGs/1SeptLille'
#path = '/Users/ibenfjordkjaersgaard/Documents/Uni/Kandidat/Semester1/DeepLearning/project/dataEEG/1SeptLille'
#os.environ['PATH'] += ':'+path
path = 'C:/Users/andre/Desktop/dataEEG/Original participant EEGs/1Sept'
os.chdir(path)
window_size = 60 
selection = ['P3']

j=0
for filename in os.listdir('.'):
    if filename.endswith('.edf'):
        raw = mne.io.read_raw_edf(filename, preload = True)
        picks = mne.pick_types(raw.info, meg=False, eeg=True, eog=False,
                       stim=False, exclude='bads', selection=selection)

        # Filter data
        raw.filter(l_freq=0.5, h_freq=40)
        freq = raw.info['sfreq']
        num_samples = raw.n_times
        lower_bound = list(range(0, int(num_samples/freq)-window_size, window_size-int(window_size/2)))
        upper_bound = list(range(window_size, int(num_samples/freq), window_size-int(window_size/2)))
        i = 0
        
        noisePicture = []

        for low, up in zip(lower_bound,upper_bound):

            raw_subset = raw.copy()
            raw_subset.crop(tmin = low, tmax = up).load_data()
            raw_subset.filter(l_freq=0.5, h_freq=40)
            data = raw_subset.get_data(picks=picks)[0]

            # if the i'te data is having added noise 
            if i in noisePicture:  
                cov = mne.make_ad_hoc_cov(raw_subset.info)
                cov['data']*= 1000**2 
                rng = np.random.RandomState(10) 
                mne.simulation.add_noise(raw_subset, cov)#, iir_filter=[0.2, -0.2, 0.04], random_state=rng)
                raw_subset.filter(l_freq=0.5, h_freq=40)
                data = raw_subset.get_data(picks=picks)[0]

                if j == 0:
                    y = [1] #finding the widows which have added noise 
                else:
                    y = np.append(y,[1], axis=0)
            else:
                data = data
                if j == 0:
                    y = [0]
                else:
                    y = np.append(y,[0], axis=0)

            ps, _, _, _ =plt.specgram(data, Fs = freq)
            s = ps.shape
            ps = ps.reshape(1,s[0], s[1], 1)


            if j == 0:
                imgs = ps
                dataTid = data
            else:
                imgs = c = np.concatenate((imgs,ps), axis=0)
                dataTid = c = np.concatenate((dataTid,data), axis=0)
                #dataTid  = np.append(dataTid,data, axis=0)

            if i == 100: # max size manually set to 101 pics per file
                break
            i+=1
            
        j+=1
dataTid=dataTid.reshape(imgs.shape[0],-1)
imgs=imgs.reshape(imgs.shape[0],-1)
yTranspose = np.transpose(y)
# Out:
# Extracting EDF parameters from C:\Users\andre\Desktop\dataEEG\Original participant EEGs\1Sept\sbs2data_2018_09_01_08_04_51_328.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227455  =      0.000 ...  1776.992 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (6.602 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 40 Hz
#
# FIR filter parameters
# ...

# %%
#datatid=datatid.reshape(imgs.shape[0],-1)
dataTid.shape
# Out:
# (1931, 7681)

# %%
#imgs=imgs.reshape(imgs.shape[0],-1)
imgs.shape
# Out:
# (1931, 7611)

# %%
## PCA Func: 
from sklearn.decomposition import PCA
#n_components=0.80 means it will return the Eigenvectors that have the 80% of the variation in the dataset
specto_pca = PCA(n_components=0.99)
specto_pca.fit(imgs)
PCAdata = specto_pca.fit_transform(imgs)

print(specto_pca.explained_variance_ratio_)  
print(PCAdata)
PCAdata.shape
# Out:
# [0.13684711 0.07611919 0.04919527 0.04456594 0.04190426 0.03475926
#  0.03287737 0.03029315 0.02982839 0.02662651 0.02543462 0.02420955
#  0.02188969 0.02138353 0.01946815 0.01828344 0.01749789 0.01680658
#  0.01552015 0.01499948 0.01455314 0.01362911 0.01283346 0.01213274
#  0.01206229 0.01165197 0.01074088 0.01031725 0.00998883 0.00911308
#  0.00897234 0.00887974 0.00801828 0.00791626 0.00727809 0.00702507
#  0.00664049 0.00616264 0.00599421 0.00556859 0.00533999 0.0052154
#  0.00482899 0.00458141 0.00447291 0.00426605 0.00393611 0.00380269
#  0.00365206 0.00362232 0.00345532 0.00335266 0.00321543 0.00290772
#  0.00288858 0.00280877 0.0025465  0.0023837  0.00222573 0.00214221
#  0.00196689 0.00191634 0.00175519 0.00171012 0.00166483 0.00155077
#  0.00147266 0.001433   0.00128994 0.00127234 0.00121842 0.00116612
#  0.00103314 0.00097315 0.00092838 0.00087799 0.00084719 0.00081797
#  0.00075755 0.00069709 0.00069334 0.00063969 0.00058153 0.00054697
# ...

# %%
pca = PCA()  # project from 64 to 2 dimensions
projected = pca.fit_transform(imgs)
print(imgs.data.shape)
print(projected.shape)

plt.scatter(projected[:, 0], projected[:, 1])
plt.xlim(1.2*projected[:,0].min(),1.2*projected[:,0].max())
plt.ylim(1.2*projected[:,1].min(),1.2*projected[:,1].max())
plt.xlabel('Principal component 1')
plt.ylabel('Principal component 2')

PCAdata.shape
# Out:
# (1931, 7611)
# (1931, 1931)
# (1931, 90)

# %%
# load data from Matlab data file
#matdata = loadmat('../Data/digits.mat')
X = np.matrix(PCAdata)
#y = np.matrix(matdata['y'])
N, M = np.shape(X)

# Restrict the data to images of "2"
#X = X[y.A.ravel()==2,:]
N, M = np.shape(X)

# %%
import numpy as np
from matplotlib.pyplot import (figure, imshow, bar, title, xticks, yticks, cm,
                               subplot, show, savefig)
from scipy.io import loadmat
from toolbox_02450 import gausKernelDensity
from sklearn.neighbors import NearestNeighbors

from scipy import stats
#X[i[1],:]
#len(imgslog[:,i[k]])

# %%
N1,M1 = 59,129
imgslog = 10*np.log10(imgs)
datatidlog = 10*np.log10(1+dataTid)

### Gausian Kernel density estimator
# cross-validate kernel width by leave-one-out-cross-validation
# (efficient implementation in gausKernelDensity function)
# evaluate for range of kernel widths
widths = X.var(axis=0).max() * (2.0**np.arange(-10,3))
logP = np.zeros(np.size(widths))
for i,w in enumerate(widths):
   print('Fold {:2d}, w={:f}'.format(i,w))
   density, log_density = gausKernelDensity(X,w)
   logP[i] = log_density.sum()
   
val = logP.max()
ind = logP.argmax()

width=widths[ind]
print('Optimal estimated width is: {0}'.format(width))

# evaluate density for estimated width
density, log_density = gausKernelDensity(X,width)

# Sort the densities
i = (density.argsort(axis=0)).ravel()
i_gauss = i 
density = density[i].reshape(-1,)

# Plot density estimate of outlier score
figure(1)
bar(range(20),density[:20])
title('Density estimate')

# Plot possible outliers
figure(2)
for k in range(0,20):
    subplot(4,5,k+1)
    #imshow(np.reshape(X[i[k]], (N1,M1)).T, cmap=cm.binary)
    plt.specgram(datatidlog[i[k],:], Fs = freq)
    if k==3: title('Gaussian Kernel Density: Possible outliers')
plt.show()

### K-neighbors density estimator
# Neighbor to use:
K = 5

# Find the k nearest neighbors
knn = NearestNeighbors(n_neighbors=K).fit(X)
D, i = knn.kneighbors(X)

density = 1./(D.sum(axis=1)/K)

# Sort the scores
i = density.argsort()
i_knn = i
density = density[i]

# Plot k-neighbor estimate of outlier score (distances)
figure(3)
bar(range(20),density[:20])
title('KNN density: Outlier score')
# Plot possible outliers
figure(4)
for k in range(0,20):
    subplot(4,5,k+1)
    #imshow(np.reshape(X[i[k]], (N1,M1)).T, cmap=cm.binary)
    plt.specgram(datatidlog[i[k],:], Fs = freq)
    if k==3: title('KNN density: Possible outliers')



### K-nearest neigbor average relative density
# Compute the average relative density

knn = NearestNeighbors(n_neighbors=K).fit(X)
D, i = knn.kneighbors(X)
density = 1./(D.sum(axis=1)/K)
avg_rel_density = density/(density[i[:,1:]].sum(axis=1)/K)

# Sort the avg.rel.densities
i_avg_rel = avg_rel_density.argsort()
avg_rel_density = avg_rel_density[i_avg_rel]

# Plot k-neighbor estimate of outlier score (distances)
figure(5)
bar(range(20),avg_rel_density[:20])
title('KNN average relative density: Outlier score')
# Plot possible outliers
figure(6)
for k in range(0,20):
    subplot(4,5,k+1)
    #imshow(np.reshape(X[i[k]], (N1,M1)).T, cmap=cm.binary)
    plt.specgram(datatidlog[i[k],:], Fs = freq)
    if k==3: title('KNN average relative density: Possible outliers')



### Distance to 5'th nearest neighbor outlier score
K = 5

# Find the k nearest neighbors
knn = NearestNeighbors(n_neighbors=K).fit(X)
D, i = knn.kneighbors(X)

# Outlier score
score = D[:,K-1]
# Sort the scores
i = score.argsort()
i_5nn = i 
score = score[i[::-1]]
print(i)

# Plot k-neighbor estimate of outlier score (distances)
figure(7)
bar(range(20),score[:20])
title('5th neighbor distance: Outlier score')
# Plot possible outliers
figure(8)
for k in range(0,20):
    subplot(4,5,k+1)
    #imshow(np.reshape(X[i[k]], (N1,M1)).T, cmap=cm.binary)
    plt.specgram(datatidlog[i[k],:], Fs = freq)
    if k==3: title('5th neighbor distance: Possible outliers')


i = np.arange(start=0, stop=20)
# Plot random digits (the first 20 in the data set), for comparison
figure(9)
for k in range(0,20):
    subplot(4,5,k+1);
    #imshow(np.reshape(X[i[k]], (N1,M1)).T, cmap=cm.binary)
    plt.specgram(datatidlog[i[k],:], Fs = freq)
    if k==3: title('Random digits from data set')    
show()
# Out:
# Fold  0, w=0.000000
# C:\Users\andre\Documents\Bachelor\DeepLearningProject\toolbox_02450.py:577: RuntimeWarning: divide by zero encountered in log
#   log_density = -np.log(N-1)-M/2*np.log(2*np.pi*width)+np.log(sQ)
# Fold  1, w=0.000000
# Fold  2, w=0.000000
# Fold  3, w=0.000000
# Fold  4, w=0.000000
# Fold  5, w=0.000000
# Fold  6, w=0.000000
# Fold  7, w=0.000000
# Fold  8, w=0.000000
# Fold  9, w=0.000000
# Fold 10, w=0.000000
# Fold 11, w=0.000000
# Fold 12, w=0.000000
# Optimal estimated width is: 1.489808632812882e-11
# C:\Users\andre\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: UserWarning: Only one segment is calculated since parameter NFFT (=256) >= signal length (=5).
# [1787 1756 1786 ... 1050  999 1051]

# %%
imgs.shape
y[0]
dataTid[0]
# Out:
# array([-1.69406589e-21, -5.07666283e-06, -1.70123408e-05, ...,
#        -2.27102530e-06, -1.22225232e-06, -4.65868121e-21])

# %%
## IMPORTANT: Test.edf cannot be from 1Sept folder!!!!

## Path to the EEG files
#path = 'E:/DeepLearningEEG/dataEEG/Original participant EEGs/1SeptLille'
#path = '/Users/ibenfjordkjaersgaard/Documents/Uni/Kandidat/Semester1/DeepLearning/project/dataEEG/Original participant EEGs/1Sept'
#os.environ['PATH'] += ':'+path
os.chdir(path)
window_size = 60 
selection = ['P3']

j=0
for filename in os.listdir('.'):
    if filename.endswith('sbs2data_2018_09_01_08_04_51_328.edf'):
        raw = mne.io.read_raw_edf(filename, preload = True)
        picks = mne.pick_types(raw.info, meg=False, eeg=True, eog=False,
                       stim=False, exclude='bads', selection=selection)

        # Filter data
        raw.filter(l_freq=0.5, h_freq=40)
        freq = raw.info['sfreq']
        num_samples = raw.n_times
        lower_bound = list(range(0, int(num_samples/freq)-window_size, window_size-int(window_size/2)))
        upper_bound = list(range(window_size, int(num_samples/freq), window_size-int(window_size/2)))
        i = 0
        
        noisePicture = []

        for low, up in zip(lower_bound,upper_bound):

            raw_subset = raw.copy()
            raw_subset.crop(tmin = low, tmax = up).load_data()
            raw_subset.filter(l_freq=0.5, h_freq=40)
            data = raw_subset.get_data(picks=picks)[0]

            # if the i'te data is having added noise 
            if i in noisePicture:  
                cov = mne.make_ad_hoc_cov(raw_subset.info)
                cov['data']*= 1000**2 
                rng = np.random.RandomState(10) 
                mne.simulation.add_noise(raw_subset, cov)#, iir_filter=[0.2, -0.2, 0.04], random_state=rng)
                raw_subset.filter(l_freq=0.5, h_freq=40)
                data = raw_subset.get_data(picks=picks)[0]

                if j == 0:
                    y = [1] #finding the widows which have added noise 
                else:
                    y = np.append(y,[1], axis=0)
            else:
                data = data
                if j == 0:
                    y_spectogram = [0]
                else:
                    y_spectogram = np.append(y_spectogram,[0], axis=0)

            ps, _, _, _ =plt.specgram(data, Fs = freq)
            s = ps.shape
            ps = ps.reshape(1,s[0], s[1], 1)


            if j == 0:
                imgs_spectogram = ps
                dataTid_spectogram = data
            else:
                imgs_spectogram = c = np.concatenate((imgs_spectogram,ps), axis=0)
                dataTid_spectogram  = np.append(dataTid_spectogram,data, axis=0)

            if i == 100: # max size manually set to 101 pics per file
                break
            i+=1
            
        j+=1
dataTid_spectogram=dataTid_spectogram.reshape(imgs_spectogram.shape[0],-1)
yTranspose_spectogram = np.transpose(y_spectogram)
# Out:
# Extracting EDF parameters from C:\Users\andre\Desktop\dataEEG\Original participant EEGs\1Sept\sbs2data_2018_09_01_08_04_51_328.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 227455  =      0.000 ...  1776.992 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (6.602 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 40 Hz
#
# FIR filter parameters
# ...

# %%
# PLot the outlierstest
dataTid_spectogram_log= 10*np.log10(dataTid_spectogram +1)
ii = projected[:,0].argmax()
a = datatidlog[ii,:]

xx,  freq, t, cax1 = plt.specgram(a, Fs=128)

def plot_specgram(data, title='', x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0], fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    pxx,  freq, t, cax = plt.specgram(data, Fs=128, vmin = -170, vmax = -40)
    fig.colorbar(cax1).set_label('Intensity [dB]')

plot_specgram(a,title='Spectrogram of outlier', x_label='Time (in seconds)', y_label='Frequency', fig_size=(14,8))

# %%
# PLot the outlierstest
dataTid_spectogram_log= 10*np.log10(dataTid_spectogram +1)
ii = projected[:,0].argmax()
a = datatidlog[ii,:]

xx,  freq, t, cax1 = plt.specgram(a, Fs=128)

def plot_specgram(data, title='', x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0], fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    pxx,  freq, t, cax = plt.specgram(data, Fs=128)
    fig.colorbar(cax).set_label('Intensity [dB]')

plot_specgram(a,title='Spectrogram of outlier', x_label='Time (in seconds)', y_label='Frequency', fig_size=(14,8))

# %%
y_true = y 
pred_index = i_5nn[np.sum(y_true):]
y_pred = np.zeros(len(datatidlog))
y_pred[pred_index] = 1

# %%
confusion_matrix(y_true,y_pred)
# Out:
# array([[514, 436],
#        [467, 514]], dtype=int64)

# %%
pred_index
# Out:
# array([  99, 1705, 1769,  238,   84,  222, 1416, 1877,  246, 1880, 1417,
#         926,  919, 1422,  923, 1829, 1911,  775,  916, 1807,   71, 1325,
#        1538,  576, 1754, 1879,  335, 1281, 1411, 1213,  773, 1286, 1657,
#        1113, 1298,   97,  909,  935,  561,  897,  274, 1318, 1297, 1658,
#          63, 1660,  802,  495, 1801, 1655,  611, 1912, 1269,  920,  662,
#        1531,  248, 1306,  578,  275,  258, 1386,  327, 1910,  917,  251,
#         810,  921, 1656,  924, 1771, 1227,  828,  320,  925,  249, 1378,
#        1231,  328,  635, 1299,  254,  255,  800, 1793, 1385,  816,  772,
#        1276,  279, 1024,  776, 1548,  922, 1822, 1229,  243, 1303,  574,
#         252,  575, 1305,  803,  815, 1908, 1273, 1321,  280,  573, 1292,
#        1811, 1115,  677,  273,  284,  934, 1105, 1331,  591,  930,  597,
#        1125,  241,  581,  804,  671,  936, 1547, 1310, 1828, 1809, 1302,
#         596,  932,  785, 1283,  277,  253,  670,  592,   62,  240, 1290,
# ...

# %%
981*2
# Out:
# 1962

# %%
y_true
# Out:
# array([0, 0, 1, ..., 1, 1, 1])
